# %%
import numpy as np
import pandas as pd

# %%
data_file_name = 'mytable.csv'

df = pd.read_csv(data_file_name, error_bad_lines=False, warn_bad_lines=False)

# %%
df.head(20)
# Out:
#        Id  PostId  PredPostBlockVersionId  RootPostBlockVersionId  Length  \
# 0    6495     683                     NaN                    6495      57
# 1    7773     972                     NaN                    7773     139
# 2    7777     972                  7773.0                    7773     139
# 3    8824    1171                     NaN                    8824      35
# 4   10032    1476                     NaN                   10032      45
# 5   10038    1476                     NaN                   10038      41
# 6   10046    1476                 10032.0                   10032      45
# 7   10050    1476                 10038.0                   10038      41
# 8   10058    1476                 10046.0                   10032      45
# 9   10061    1476                 10050.0                   10038      41
# 10  10064    1476                 10058.0                   10032      45
# 11  10066    1476                 10061.0                   10038      41
# 12  10069    1476                 10064.0                   10032      45
# 13  10071    1476                 10066.0                   10038      41
# 14  10074    1476                 10069.0                   10032      45
# 15  10076    1476                 10071.0                   10038      41
# 16  10079    1476                 10074.0                   10032      45
# 17  10081    1476                 10076.0                   10038      41
# 18  10084    1476                 10079.0                   10032      45
# 19  10086    1476                 10081.0                   10038      41
#
#     LineCount                                               Tags  \
# 0           1                        <python><arrays><iteration>
# 1           4             <python><oop><methods><monkeypatching>
# 2           4             <python><oop><methods><monkeypatching>
# 3           1  <python><performance><data-structures><graph-t...
# 4           4        <python><syntax><binary><integer><literals>
# 5           4        <python><syntax><binary><integer><literals>
# 6           4        <python><syntax><binary><integer><literals>
# 7           4        <python><syntax><binary><integer><literals>
# 8           4        <python><syntax><binary><integer><literals>
# 9           4        <python><syntax><binary><integer><literals>
# 10          4        <python><syntax><binary><integer><literals>
# 11          4        <python><syntax><binary><integer><literals>
# 12          4        <python><syntax><binary><integer><literals>
# 13          4        <python><syntax><binary><integer><literals>
# 14          4        <python><syntax><binary><integer><literals>
# 15          4        <python><syntax><binary><integer><literals>
# 16          4        <python><syntax><binary><integer><literals>
# 17          4        <python><syntax><binary><integer><literals>
# 18          4        <python><syntax><binary><integer><literals>
# 19          4        <python><syntax><binary><integer><literals>
#
#                                               Content
# 0   foo in iter_attr(array of python objects, attr...
# 1       from SomeOtherProduct.SomeModule import So...
# 2       from SomeOtherProduct.SomeModule import So...
# 3                     graph[I][J][Property"]="value""
# 4        >>> 0x12AF\n    4783\n    >>> 0x100\n    256
# 5            >>> 01267\n    695\n    >>> 0100\n    64
# 6        >>> 0x12AF\n    4783\n    >>> 0x100\n    256
# 7            >>> 01267\n    695\n    >>> 0100\n    64
# 8        >>> 0x12AF\n    4783\n    >>> 0x100\n    256
# 9            >>> 01267\n    695\n    >>> 0100\n    64
# 10       >>> 0x12AF\n    4783\n    >>> 0x100\n    256
# 11           >>> 01267\n    695\n    >>> 0100\n    64
# 12       >>> 0x12AF\n    4783\n    >>> 0x100\n    256
# 13           >>> 01267\n    695\n    >>> 0100\n    64
# 14       >>> 0x12AF\n    4783\n    >>> 0x100\n    256
# 15           >>> 01267\n    695\n    >>> 0100\n    64
# 16       >>> 0x12AF\n    4783\n    >>> 0x100\n    256
# 17           >>> 01267\n    695\n    >>> 0100\n    64
# 18       >>> 0x12AF\n    4783\n    >>> 0x100\n    256
# 19           >>> 01267\n    695\n    >>> 0100\n    64

# %%
s = df.loc[30,'Content']
print(bytearray(s, 'utf8').decode('unicode_escape'))
s
# Out:
#     import sys
#     print "Menu
#     1) Say Foo
#     2) Say Bar"""
#     answer = raw_input("Make a selection> ")
#     if "1" in answer: print "foo"
#     elif "2" in answer: print "bar""
# '    import sys\\n    print "Menu\\n    1) Say Foo\\n    2) Say Bar"""\\n    answer = raw_input("Make a selection> ")\\n    if "1" in answer: print "foo"\\n    elif "2" in answer: print "bar""'

# %%
row = df.iloc[30,:]
row['Content']
# Out:
# '    import sys\\n    print "Menu\\n    1) Say Foo\\n    2) Say Bar"""\\n    answer = raw_input("Make a selection> ")\\n    if "1" in answer: print "foo"\\n    elif "2" in answer: print "bar""'
